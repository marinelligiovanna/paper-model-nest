# %%
from pynest.packing import BLPacker, BLBin
from pynest.elements.rect import Rect
import os
from xml.dom import minidom
import lxml.etree as xmltree
from pynest.elements.piece import Piece
from pynest.elements.viewbox import ViewBox
from pynest.utils import create_rectangle
from pynest.elements.papermodel import PaperModel
from pynest.elements.boundingrect import MinBoundingRect
from pynest.elements.rect import Rect
import matplotlib.pyplot as plt

# %%
data_path = f"{os.getcwd()}/pynest/data/svgs"

# %%
model = PaperModel(f'{data_path}/harry-potter.svg')
# Out:
# /workspaces/paper-model-nest/pynest/elements/segment.py:45: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.arctan(deltaY/deltaX)

# %%
piece = model.pieces[20]
points = [s.points for s in piece.segments]
points = list(set(points))

for p in points:
    x = p[0]
    y = p[1]
    plt.plot(x,y, 'k-', lw=1)

# %%
rects = []

for piece in model.pieces:
    br = MinBoundingRect(piece)
    rects.append(br)

rects[2].plot()

# %%
rects[1].plot()

# %%
packer = BLPacker(297,210, rects)
packer.pack()
# Out:
# Creating new bin!
# Creating new bin!
# Creating new bin!

# %%
plt.figure(figsize=(9,6))
plt.title("Bin 1")
packer.bins[0].plot()

# %%
packer.bins[1].plot()

# %%
packer.bins[2].plot()

# %%
rects[0].height
# Out:
# 19.882089997613633

# %%
rects[0].width
# Out:
# 74.8731609839673

# %%
19.882089997613633 * 74.8731609839673
# Out:
# 1488.6349250890514

# %%
r =Rect(0.0, 0.0, 651.3408268550023, 82.39303881978884)
r.plot()
